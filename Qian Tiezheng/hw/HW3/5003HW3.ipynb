# %% [markdown]
# (a)

# %%
import numpy as mp
import math
import matplotlib.pyplot as plt
# %matplotlib inline
X = np.linspace(-10,10,201)
Y = np.zeros(201)

for i in range(len(X)):
    su = 0
    delta = 0.01
    y = np.linspace(-3,3,1000)
    for va in y:
        if va+X[i]>=-3 and va+X[i] <=3:
            su+=np.sin(2*np.pi*va)*np.sin(2*np.pi*(va+X[i]))*delta
    Y[i] = su
fig = plt.figure(figsize=(8,6))
ax = plt.subplot()
ax.set_title('HW3 (a)correlation')
ax.set_xlabel('x')
ax.set_ylabel('the cross correlation of s0 with itself')
ax.plot(X,Y)
plt.show()

# %% [markdown]
# (b)

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def r_func(x,delta):
    return 1/(2*np.pi*delta**2)**0.5*np.exp(-x**2/(2*delta**2))

def s_func(x):
    return 

def create_plt(std = 0.2):
    X = np.linspace(-10,10,201)
    Y = np.zeros(201)

    for i in range(len(X)):

        y = np.linspace(-3,3,1000)
        delta = y[1]-y[0]
        su = 0
        for dot in y:
            su += (np.sin(2*np.pi*dot)+np.sin(20*np.pi*dot))*r_func(X[i]-dot,std)*delta
        Y[i] = su
    ax.plot(X,Y,label = 'std = '+str(round(std,2)))


fig = plt.figure(figsize = (8,6))
ax = plt.subplot()
for i in range(1,6):
    std = i*0.2
    create_plt(std)
ax.set_xlabel('x')
ax.set_ylabel('the convolution (s*r)(x)')
ax.set_title('(b)convolution')

plt.legend()
plt.show()
