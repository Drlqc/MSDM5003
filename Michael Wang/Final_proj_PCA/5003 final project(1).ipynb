# %%
import pandas as pd
import numpy as np
import os
import re
import datetime

# %%
df=pd.read_excel('eigenvalue and eigen vector.xlsx')

# %%
#basic materials
range1=[12,14,31,34,37,42,44,46,51,54]
#consumer goods
range2=[4,18,3,30,33,40,47,59,64,65]
#Financials
range3=[2,7,9,10,11,13,16,19,21,22,25,32,36,38,39,41,48,49,53,55,58,63]
#health care
range4=[8,23,26,50,52,56]
#industrials
range5=[1,6,15,20,24,27,28,29,35,60]
#oil and gas
range6=[17,45,57,66]
#technology
range7=[5,62]
#telecommunications
range8=[61]
#utilities
range9=[43]

# %%
import matplotlib.pyplot as plt
df[['Unnamed: 0',1,2]].loc[1:]
# Out:
#    Unnamed: 0         1         2
# 1   ABC_close  0.123265 -0.010864
# 2   AFI_close  0.120436  0.069267
# 3   ALL_close  0.084632  0.021335
# 4   ALQ_close  0.126192 -0.173495
# 5   ALU_close  0.050006 -0.030973
# ..        ...       ...       ...
# 62  TNE_close  0.063713 -0.000025
# 63  WBC_close  0.163103  0.049448
# 64  WES_close  0.141022  0.051510
# 65  WOW_close  0.100731  0.099698
# 66  WPL_close  0.140224  0.217964
#
# [66 rows x 3 columns]

# %%
plt.figure(figsize=(12,10))
k=1
# for i in range1:
#     plt.scatter(df[1].loc[i],df[2].loc[i],label=df['Unnamed: 0'].loc[i],color='red')
plt.scatter(df[k].loc[range1],df[k+1].loc[range1],color='red',label='Basic materials')
# for i in range2:
plt.scatter(df[k].loc[range2],df[k+1].loc[range2],color='black',label='Consumer goods')
# for i in range3:
plt.scatter(df[k].loc[range3],df[k+1].loc[range3],color='green',label='Financials')
# for i in range4:
plt.scatter(df[k].loc[range4],df[k+1].loc[range4],color='blue',label='Health care')
# for i in range5:
plt.scatter(df[k].loc[range5],df[k+1].loc[range5],color='orange',label='Industrials')
# for i in range6:
plt.scatter(df[k].loc[range6],df[k+1].loc[range6],color='yellow',label='Oil and gas')
# for i in range7:
plt.scatter(df[k].loc[range7],df[k+1].loc[range7],color='purple',label='Technology')
# for i in range8:
plt.scatter(df[k].loc[range8],df[k+1].loc[range8],color='darkseagreen',label='Telecommunications')
# for i in range9:
plt.scatter(df[k].loc[range9],df[k+1].loc[range9],color='skyblue',label='Utilities')


plt.axhline(0,linestyle='--')
plt.axvline(0,linestyle='--')

# plt.text(-0.1,0,'$\\star$',fontsize=50,color='red')
plt.legend()
plt.title('Component %d verus component %d'%(k+1,k))
plt.xlabel('component %d'%k)
plt.ylabel('component %d'%(k+1))
plt.savefig('Component %d verus component %d.png'%(k+1,k))

# %%
plt.figure(figsize=(12,10))
k=3
# for i in range1:
#     plt.scatter(df[1].loc[i],df[2].loc[i],label=df['Unnamed: 0'].loc[i],color='red')
plt.scatter(df[k].loc[range1],df[k+1].loc[range1],color='red',label='Basic materials')
# for i in range2:
plt.scatter(df[k].loc[range2],df[k+1].loc[range2],color='black',label='Consumer goods')
# for i in range3:
plt.scatter(df[k].loc[range3],df[k+1].loc[range3],color='green',label='Financials')
# for i in range4:
plt.scatter(df[k].loc[range4],df[k+1].loc[range4],color='blue',label='Health care')
# for i in range5:
plt.scatter(df[k].loc[range5],df[k+1].loc[range5],color='orange',label='Industrials')
# for i in range6:
plt.scatter(df[k].loc[range6],df[k+1].loc[range6],color='yellow',label='Oil and gas')
# for i in range7:
plt.scatter(df[k].loc[range7],df[k+1].loc[range7],color='purple',label='Technology')
# for i in range8:
plt.scatter(df[k].loc[range8],df[k+1].loc[range8],color='darkseagreen',label='Telecommunications')
# for i in range9:
plt.scatter(df[k].loc[range9],df[k+1].loc[range9],color='skyblue',label='Utilities')


plt.axhline(0,linestyle='--')
plt.axvline(0,linestyle='--')

# plt.text(-0.1,0,'$\\star$',fontsize=50,color='red')
plt.legend()
plt.title('Component %d verus component %d'%(k+1,k))
plt.xlabel('component %d'%k)
plt.ylabel('component %d'%(k+1))
plt.savefig('Component %d verus component %d.png'%(k+1,k))

# %%
plt.figure(figsize=(12,10))
k=5
# for i in range1:
#     plt.scatter(df[1].loc[i],df[2].loc[i],label=df['Unnamed: 0'].loc[i],color='red')
plt.scatter(df[k].loc[range1],df[k+1].loc[range1],color='red',label='Basic materials')
# for i in range2:
plt.scatter(df[k].loc[range2],df[k+1].loc[range2],color='black',label='Consumer goods')
# for i in range3:
plt.scatter(df[k].loc[range3],df[k+1].loc[range3],color='green',label='Financials')
# for i in range4:
plt.scatter(df[k].loc[range4],df[k+1].loc[range4],color='blue',label='Health care')
# for i in range5:
plt.scatter(df[k].loc[range5],df[k+1].loc[range5],color='orange',label='Industrials')
# for i in range6:
plt.scatter(df[k].loc[range6],df[k+1].loc[range6],color='yellow',label='Oil and gas')
# for i in range7:
plt.scatter(df[k].loc[range7],df[k+1].loc[range7],color='purple',label='Technology')
# for i in range8:
plt.scatter(df[k].loc[range8],df[k+1].loc[range8],color='darkseagreen',label='Telecommunications')
# for i in range9:
plt.scatter(df[k].loc[range9],df[k+1].loc[range9],color='skyblue',label='Utilities')


plt.axhline(0,linestyle='--')
plt.axvline(0,linestyle='--')

# plt.text(-0.1,0,'$\\star$',fontsize=50,color='red')
plt.legend()
plt.title('Component %d verus component %d'%(k+1,k))
plt.xlabel('component %d'%k)
plt.ylabel('component %d'%(k+1))
plt.savefig('Component %d verus component %d.png'%(k+1,k))

# %%
plt.figure(figsize=(12,10))
k=7
# for i in range1:
#     plt.scatter(df[1].loc[i],df[2].loc[i],label=df['Unnamed: 0'].loc[i],color='red')
plt.scatter(df[k].loc[range1],df[k+1].loc[range1],color='red',label='Basic materials')
# for i in range2:
plt.scatter(df[k].loc[range2],df[k+1].loc[range2],color='black',label='Consumer goods')
# for i in range3:
plt.scatter(df[k].loc[range3],df[k+1].loc[range3],color='green',label='Financials')
# for i in range4:
plt.scatter(df[k].loc[range4],df[k+1].loc[range4],color='blue',label='Health care')
# for i in range5:
plt.scatter(df[k].loc[range5],df[k+1].loc[range5],color='orange',label='Industrials')
# for i in range6:
plt.scatter(df[k].loc[range6],df[k+1].loc[range6],color='yellow',label='Oil and gas')
# for i in range7:
plt.scatter(df[k].loc[range7],df[k+1].loc[range7],color='purple',label='Technology')
# for i in range8:
plt.scatter(df[k].loc[range8],df[k+1].loc[range8],color='darkseagreen',label='Telecommunications')
# for i in range9:
plt.scatter(df[k].loc[range9],df[k+1].loc[range9],color='skyblue',label='Utilities')


plt.axhline(0,linestyle='--')
plt.axvline(0,linestyle='--')

# plt.text(-0.1,0,'$\\star$',fontsize=50,color='red')
plt.legend()
plt.title('Component %d verus component %d'%(k+1,k))
plt.xlabel('component %d'%k)
plt.ylabel('component %d'%(k+1))
plt.savefig('Component %d verus component %d.png'%(k+1,k))

# %%
plt.figure(figsize=(12,10))
k=9
# for i in range1:
#     plt.scatter(df[1].loc[i],df[2].loc[i],label=df['Unnamed: 0'].loc[i],color='red')
plt.scatter(df[k].loc[range1],df[k+1].loc[range1],color='red',label='Basic materials')
# for i in range2:
plt.scatter(df[k].loc[range2],df[k+1].loc[range2],color='black',label='Consumer goods')
# for i in range3:
plt.scatter(df[k].loc[range3],df[k+1].loc[range3],color='green',label='Financials')
# for i in range4:
plt.scatter(df[k].loc[range4],df[k+1].loc[range4],color='blue',label='Health care')
# for i in range5:
plt.scatter(df[k].loc[range5],df[k+1].loc[range5],color='orange',label='Industrials')
# for i in range6:
plt.scatter(df[k].loc[range6],df[k+1].loc[range6],color='yellow',label='Oil and gas')
# for i in range7:
plt.scatter(df[k].loc[range7],df[k+1].loc[range7],color='purple',label='Technology')
# for i in range8:
plt.scatter(df[k].loc[range8],df[k+1].loc[range8],color='darkseagreen',label='Telecommunications')
# for i in range9:
plt.scatter(df[k].loc[range9],df[k+1].loc[range9],color='skyblue',label='Utilities')


plt.axhline(0,linestyle='--')
plt.axvline(0,linestyle='--')

# plt.text(-0.1,0,'$\\star$',fontsize=50,color='red')
plt.legend()
plt.title('Component %d verus component %d'%(k+1,k))
plt.xlabel('component %d'%k)
plt.ylabel('component %d'%(k+1))
plt.savefig('Component %d verus component %d.png'%(k+1,k))

# %%
plt.figure(figsize=(12,10))
k=11
# for i in range1:
#     plt.scatter(df[1].loc[i],df[2].loc[i],label=df['Unnamed: 0'].loc[i],color='red')
plt.scatter(df[k].loc[range1],df[k+1].loc[range1],color='red',label='Basic materials')
# for i in range2:
plt.scatter(df[k].loc[range2],df[k+1].loc[range2],color='black',label='Consumer goods')
# for i in range3:
plt.scatter(df[k].loc[range3],df[k+1].loc[range3],color='green',label='Financials')
# for i in range4:
plt.scatter(df[k].loc[range4],df[k+1].loc[range4],color='blue',label='Health care')
# for i in range5:
plt.scatter(df[k].loc[range5],df[k+1].loc[range5],color='orange',label='Industrials')
# for i in range6:
plt.scatter(df[k].loc[range6],df[k+1].loc[range6],color='yellow',label='Oil and gas')
# for i in range7:
plt.scatter(df[k].loc[range7],df[k+1].loc[range7],color='purple',label='Technology')
# for i in range8:
plt.scatter(df[k].loc[range8],df[k+1].loc[range8],color='darkseagreen',label='Telecommunications')
# for i in range9:
plt.scatter(df[k].loc[range9],df[k+1].loc[range9],color='skyblue',label='Utilities')


plt.axhline(0,linestyle='--')
plt.axvline(0,linestyle='--')

# plt.text(-0.1,0,'$\\star$',fontsize=50,color='red')
plt.legend()
plt.title('Component %d verus component %d'%(k+1,k))
plt.xlabel('component %d'%k)
plt.ylabel('component %d'%(k+1))
plt.savefig('Component %d verus component %d.png'%(k+1,k))

# %%
plt.plot(df.iloc[0,1:])
plt.scatter(10,df[10].loc[0],color='red')
plt.xlabel('component')
plt.ylabel('eigenvalue')
plt.title('Eigenvalue versus component')
plt.savefig('Eigenvalue versus component.png')

# %%
plt.figure(figsize=(12,10))
k=11
# for i in range1:
#     plt.scatter(df[1].loc[i],df[2].loc[i],label=df['Unnamed: 0'].loc[i],color='red')
plt.scatter(df[k].loc[range1],df[k+1].loc[range1],color='red',label='Basic materials')
# for i in range2:
plt.scatter(df[k].loc[range2],df[k+1].loc[range2],color='black',label='Consumer goods')
# for i in range3:
plt.scatter(df[k].loc[range3],df[k+1].loc[range3],color='green',label='Financials')
# for i in range4:
plt.scatter(df[k].loc[range4],df[k+1].loc[range4],color='blue',label='Health care')
# for i in range5:
plt.scatter(df[k].loc[range5],df[k+1].loc[range5],color='orange',label='Industrials')
# for i in range6:
plt.scatter(df[k].loc[range6],df[k+1].loc[range6],color='yellow',label='Oil and gas')
# for i in range7:
plt.scatter(df[k].loc[range7],df[k+1].loc[range7],color='purple',label='Technology')
# for i in range8:
plt.scatter(df[k].loc[range8],df[k+1].loc[range8],color='darkseagreen',label='Telecommunications')
# for i in range9:
plt.scatter(df[k].loc[range9],df[k+1].loc[range9],color='skyblue',label='Utilities')


plt.axhline(0,linestyle='--')
plt.axvline(0,linestyle='--')

# plt.text(-0.1,0,'$\\star$',fontsize=50,color='red')
plt.legend()
plt.title('Component %d verus component %d'%(k+1,k))
plt.xlabel('component %d'%k)
plt.ylabel('component %d'%(k+1))
plt.savefig('Component %d verus component %d.png'%(k+1,k))

# %%
df.head(10)
# Out:
#     Unnamed: 0          1         2         3         4         5         6  \
# 0  eigenvalues  19.411830  4.141725  2.559374  1.802498  1.463109  1.384663
# 1    ABC_close   0.123265 -0.010864  0.054040  0.017572  0.048628 -0.120452
# 2    AFI_close   0.120436  0.069267  0.011040  0.089855  0.111545 -0.081273
# 3    ALL_close   0.084632  0.021335 -0.152111 -0.294897  0.116817  0.089859
# 4    ALQ_close   0.126192 -0.173495  0.156537 -0.089622 -0.120358  0.127362
# 5    ALU_close   0.050006 -0.030973 -0.081839 -0.182407 -0.027252  0.143304
# 6    AMC_close   0.130083 -0.150703 -0.013789 -0.097651 -0.060123  0.053147
# 7    AMP_close   0.127338  0.000445 -0.106949 -0.016352 -0.016178  0.036788
# 8    ANN_close   0.103621 -0.144842 -0.042995 -0.262017 -0.045533  0.170146
# 9    ANZ_close   0.160131  0.059867 -0.157211  0.314696  0.040401  0.030145
#
#           7         8         9  ...        57        58        59        60  \
# ...
